# %%
import pandas as pd

# %%
aid = pd.read_csv('university-aid.csv')

# %%
aid.head(50)
# Out:
#                           Institution  Total Cost of Attendance  \
# 0       U. of Massachusetts - Amherst                   31000.0
# 1                       U. of Alabama                   26482.0
# 2                   New C. of Florida                   20650.0
# 3                 U. of Maine - Orono                   25088.0
# 4                       U. of Florida                       0.0
# 5            St. John's C. - Santa Fe                   50170.0
# 6                         The Citadel                   34317.0
# 7               U. of Hawaii - Manoa                    28855.0
# 8                       U. of Vermont                   24550.0
# 9                Eastern Michigan U.                    23952.0
# 10                        Skidmore C.                   71781.0
# 11                  U. of Mississippi                   25762.0
# 12          Southeastern Louisiana U.                   21925.0
# 13                   James Madison U.                   26230.0
# ...

# %%
 aid.Institution = aid.Institution.str.replace('U.', 'University', regex=False)

# %%
aid.Institution=aid.Institution.str.replace('C.', 'College', regex=False)

# %%
aid.Institution = aid.Institution.str.replace('Inst.', 'Institute', regex=False).str.replace('Inst ', 'Institute ', regex=False)

# %%
aid.Institution = aid.Institution.str.replace('Mass.', 'Massachusetts', regex=False)

# %%
aid.Institution = aid.Institution.str.replace('Tech.', 'Technology', regex=False)

# %%
aid.Institution = aid.Institution.str.replace('Cal.', 'California', regex=False)

# %%
aid.head(50)
# Out:
#                                       Institution  Total Cost of Attendance  \
# 0           University of Massachusetts - Amherst                   31000.0
# 1                           University of Alabama                   26482.0
# 2                          New College of Florida                   20650.0
# 3                     University of Maine - Orono                   25088.0
# 4                           University of Florida                       0.0
# 5                   St. John's College - Santa Fe                   50170.0
# 6                                     The Citadel                   34317.0
# 7                   University of Hawaii - Manoa                    28855.0
# 8                           University of Vermont                   24550.0
# 9                    Eastern Michigan University                    23952.0
# 10                               Skidmore College                   71781.0
# ...

# %%
colleges = pd.read_csv('colleges-abridged.csv')

# %%
colleges = colleges.head(79)

# %%
colleges
# Out:
#                                   University  Large  Medium Public  \
# 0      Massachusetts Institute of Technology  False    True  False
# 1                        Stanford University  False    True  False
# 2                            Yale University  False    True  False
# 3                         Harvard University  False    True  False
# 4                       Princeton University  False    True  False
# ..                                       ...    ...     ...    ...
# 74  University of California - Santa Barbara   True   False   True
# 75                   University of Rochester  False    True  False
# 76             Southern Methodist University  False    True  False
# 77                  Brigham Young University   True   False  False
# 78           Case Western Reserve University  False    True  False
#
#     Liberal Arts  Small  Rank Private
# 0          False  False   1.0    True
# 1          False  False   2.0    True
# 2          False  False   3.0    True
# ...

# %%
colleges[~colleges.University.isin(aid.Institution)]
# Out:
#                                            University  Large  Medium Public  \
# 3                                  Harvard University  False    True  False
# 13                 Washington University in St. Louis  False    True  False
# 29                                   Emory University  False    True  False
# 36       United States Military Academy at West Point  False    True   True
# 42        University of North Carolina at Chapel Hill   True   False   True
# 50                       University of Texas - Austin   True   False   True
# 55                                     William & Mary  False    True   True
# 62                            University of Wisconsin   True   False   True
# 63         University of Illinois at Urbana-Champaign   True   False   True
# 67  The Cooper Union for the Advancement of Scienc...  False   False  False
# 71                                     Kenyon College  False   False  False
# ...

# %%
aid[aid.Institution.str.contains('Harvard')].Institution.replace('\s', '_', regex=True)
# Out:
# 40    Harvard_University_
# Name: Institution, dtype: object

# %%
aid.Institution.str.replace('\s$','_', regex=True)[aid.Institution.str.replace('\s$','_', regex=True).str.contains('_')]
# Out:
# 7                   University of Hawaii - Manoa_
# 9                    Eastern Michigan University_
# 40                            Harvard University_
# 46                    University of North Dakota_
# 57                                Kenyon College_
# 84                         University of Arizona_
# 101                 University of Texas - Austin_
# 154    University of North Carolina - Chap. Hill_
# 158     University of North Carolina - Charlotte_
# 162                              Earlham College_
# 165                                Union College_
# 188                            Mercer University_
# 225                            Kalamazoo College_
# 244                          Lawrence University_
# 273                  College of William and Mary_
# 303             Illinois Institute of Technology_
# 470                    University of New Orleans_
# 478              University of Texas - Arlington_
# Name: Institution, dtype: object

# %%
aid.Institution = aid.Institution.str.replace('\s$', '', regex=True)

# %%
colleges[~colleges.University.isin(aid.Institution)]
# Out:
#                                            University  Large  Medium Public  \
# 13                 Washington University in St. Louis  False    True  False
# 29                                   Emory University  False    True  False
# 36       United States Military Academy at West Point  False    True   True
# 42        University of North Carolina at Chapel Hill   True   False   True
# 55                                     William & Mary  False    True   True
# 62                            University of Wisconsin   True   False   True
# 63         University of Illinois at Urbana-Champaign   True   False   True
# 67  The Cooper Union for the Advancement of Scienc...  False   False  False
# 74           University of California - Santa Barbara   True   False   True
# 77                           Brigham Young University   True   False  False
#
#     Liberal Arts  Small  Rank Private
# 13         False  False  14.0    True
# 29         False  False  30.0    True
# ...

# %%
colleges.University[colleges.University.str.contains('Washington University')]
# Out:
# 13    Washington University in St. Louis
# Name: University, dtype: object

# %%
aid.Institution[aid.Institution.str.contains('Washington University')]
# Out:
# 199    Washington University in  St. Louis
# 330           George Washington University
# 492          Western Washington University
# Name: Institution, dtype: object

# %%
aid.Institution = aid.Institution.str.replace('  ', ' ', regex=False)

# %%
colleges[~colleges.University.isin(aid.Institution)]
# Out:
#                                            University  Large  Medium Public  \
# 29                                   Emory University  False    True  False
# 36       United States Military Academy at West Point  False    True   True
# 42        University of North Carolina at Chapel Hill   True   False   True
# 55                                     William & Mary  False    True   True
# 62                            University of Wisconsin   True   False   True
# 63         University of Illinois at Urbana-Champaign   True   False   True
# 67  The Cooper Union for the Advancement of Scienc...  False   False  False
# 74           University of California - Santa Barbara   True   False   True
# 77                           Brigham Young University   True   False  False
#
#     Liberal Arts  Small  Rank Private
# 29         False  False  30.0    True
# 36          True  False  37.0   False
# 42         False  False  43.0   False
# 55         False  False  56.0   False
# ...

# %%
aid = aid.rename(columns={'Institution': 'University'})

# %%
aid[aid.University.str.contains('University of California')]
# Out:
#                                   University  Total Cost of Attendance  \
# 18    University of California - Los Angeles                   34831.0
# 59   University of California - Sta. Barbara                   36685.0
# 118     University of California - Riverside                   36953.0
# 157         University of California - Davis                   35752.0
# 161     University of California - San Diego                   33606.0
# 215        University of California - Merced                   36020.0
# 230     University of California - Sta. Cruz                   37186.0
# 257      University of California - Berkeley                   36410.0
# 457        University of California - Irvine                   63000.0
#
#      Full-Time Undergrads  Full-Time Nonresident Aliens   \
# 18                34831.0                         3645.0
# 59                36685.0                         2743.0
# 118               36953.0                          697.0
# ...

# %%
aid.University = aid.University.str.replace('Sta.', 'Santa', regex=False)

# %%
colleges[~colleges.University.isin(aid.University)]
# Out:
#                                            University  Large  Medium Public  \
# 29                                   Emory University  False    True  False
# 36       United States Military Academy at West Point  False    True   True
# 42        University of North Carolina at Chapel Hill   True   False   True
# 55                                     William & Mary  False    True   True
# 62                            University of Wisconsin   True   False   True
# 63         University of Illinois at Urbana-Champaign   True   False   True
# 67  The Cooper Union for the Advancement of Scienc...  False   False  False
# 77                           Brigham Young University   True   False  False
#
#     Liberal Arts  Small  Rank Private
# 29         False  False  30.0    True
# 36          True  False  37.0   False
# 42         False  False  43.0   False
# 55         False  False  56.0   False
# 62         False  False  63.0   False
# 63         False  False  64.0   False
# ...

# %%
colleges.University = colleges.University.str.replace('University of Wisconsin', 'University of Wisconsin - Madison', regex=False)
colleges[~colleges.University.isin(aid.University)]
# Out:
#                                            University  Large  Medium Public  \
# 29                                   Emory University  False    True  False
# 36       United States Military Academy at West Point  False    True   True
# 42        University of North Carolina at Chapel Hill   True   False   True
# 55                                     William & Mary  False    True   True
# 63         University of Illinois at Urbana-Champaign   True   False   True
# 67  The Cooper Union for the Advancement of Scienc...  False   False  False
# 77                           Brigham Young University   True   False  False
#
#     Liberal Arts  Small  Rank Private
# 29         False  False  30.0    True
# 36          True  False  37.0   False
# 42         False  False  43.0   False
# 55         False  False  56.0   False
# 63         False  False  64.0   False
# 67         False   True  68.0   False
# 77         False  False  78.0   False

# %%
aid[aid.University.str.contains('Emory')]
# Out:
#                           University  Total Cost of Attendance  \
# 155  Emory University/Oxford College                   70000.0
# 192          Emory and Henry College                   50367.0
#
#      Full-Time Undergrads  Full-Time Nonresident Aliens   \
# 155               70000.0                         1118.0
# 192               50367.0                            4.0
#
#      Percentage of Nonresident Aliens to All Undergrads  Policy: Need-based  \
# 155                                               16.0                 True
# 192                                                1.0                False
#
#      Policy: Merit  Policy: No Aid  \
# 155           True           False
# 192           True           False
#
#      Percentage of Nonresident Aliens Receiving Aid  Average Aid Award  \
# 155                                             8.0            45671.0
# 192                                           100.0            21875.0
#
# ...

# %%
aid.University = aid.University.str.replace('Emory University/Oxford College', 'Emory University', regex=False)

# %%
aid[aid.University.str.contains('William')]
# Out:
#                            University  Total Cost of Attendance  \
# 25                   Williams College                   75520.0
# 273       College of William and Mary                   38889.0
# 283         Roger Williams University                   54642.0
# 316  Hobart and William Smith College                   73710.0
# 494            William Jewell College                       NaN
#
#      Full-Time Undergrads  Full-Time Nonresident Aliens   \
# 25                75520.0                          158.0
# 273               38889.0                          381.0
# 283               54642.0                           74.0
# 316               73710.0                          122.0
# 494                   NaN                            NaN
#
#      Percentage of Nonresident Aliens to All Undergrads  Policy: Need-based  \
# 25                                                 8.0                 True
# 273                                                6.0                False
# ...

# %%
colleges.University = colleges.University.str.replace('William & Mary', 'College of William and Mary', regex=False)

# %%
colleges[~colleges.University.isin(aid.University)]
# Out:
#                                            University  Large  Medium Public  \
# 36       United States Military Academy at West Point  False    True   True
# 42        University of North Carolina at Chapel Hill   True   False   True
# 63         University of Illinois at Urbana-Champaign   True   False   True
# 67  The Cooper Union for the Advancement of Scienc...  False   False  False
# 77                           Brigham Young University   True   False  False
#
#     Liberal Arts  Small  Rank Private
# 36          True  False  37.0   False
# 42         False  False  43.0   False
# 63         False  False  64.0   False
# 67         False   True  68.0   False
# 77         False  False  78.0   False

# %%
aid[aid.University.str.contains('Cooper')]
# Out:
#        University  Total Cost of Attendance  Full-Time Undergrads  \
# 365  Cooper Union                       NaN                   NaN
#
#      Full-Time Nonresident Aliens   \
# 365                            NaN
#
#      Percentage of Nonresident Aliens to All Undergrads  Policy: Need-based  \
# 365                                                NaN                False
#
#      Policy: Merit  Policy: No Aid  \
# 365           True           False
#
#      Percentage of Nonresident Aliens Receiving Aid  Average Aid Award  \
# 365                                             NaN                NaN
#
#      Average Cost with Aid  Expected Cost
# 365                    NaN            NaN

# %%
colleges.University = colleges.University.replace(to_replace='.+Cooper.+', value='Cooper Union', regex=True)

# %%
aid.University = aid.University.str.replace('Brigham.+', 'Brigham Young University', regex=True)

# %%
aid[aid.University.str.contains('Brigham')]
# Out:
#                   University  Total Cost of Attendance  Full-Time Undergrads  \
# 51  Brigham Young University                   19236.0               19236.0
#
#     Full-Time Nonresident Aliens   \
# 51                         1026.0
#
#     Percentage of Nonresident Aliens to All Undergrads  Policy: Need-based  \
# 51                                                4.0                 True
#
#     Policy: Merit  Policy: No Aid  \
# 51           True           False
#
#     Percentage of Nonresident Aliens Receiving Aid  Average Aid Award  \
# 51                                            52.0             5704.0
#
#     Average Cost with Aid  Expected Cost
# 51                13532.0        16289.0

# %%
colleges[~colleges.University.isin(aid.University)]
# Out:
#                                       University  Large  Medium Public  \
# 36  United States Military Academy at West Point  False    True   True
# 42   University of North Carolina at Chapel Hill   True   False   True
# 63    University of Illinois at Urbana-Champaign   True   False   True
#
#     Liberal Arts  Small  Rank Private
# 36          True  False  37.0   False
# 42         False  False  43.0   False
# 63         False  False  64.0   False

# %%
colleges = colleges.drop(index=36)

# %%
colleges[~colleges.University.isin(aid.University)]
# Out:
#                                      University  Large  Medium Public  \
# 42  University of North Carolina at Chapel Hill   True   False   True
# 63   University of Illinois at Urbana-Champaign   True   False   True
#
#     Liberal Arts  Small  Rank Private
# 42         False  False  43.0   False
# 63         False  False  64.0   False

# %%
aid[aid.University.str.contains('Hill')]
# Out:
#                                     University  Total Cost of Attendance  \
# 53                           Hillsdale College                   42958.0
# 154  University of North Carolina - Chap. Hill                   24294.0
# 437                      Seton Hill University                       NaN
#
#      Full-Time Undergrads  Full-Time Nonresident Aliens   \
# 53                42958.0                           20.0
# 154               24294.0                          656.0
# 437                   NaN                            NaN
#
#      Percentage of Nonresident Aliens to All Undergrads  Policy: Need-based  \
# 53                                                 1.0                 True
# 154                                                4.0                False
# 437                                                NaN                False
#
#      Policy: Merit  Policy: No Aid  \
# 53            True           False
# 154           True            True
# ...

# %%
temp = aid.University.str.replace('University of North Carolina .+ Hill', 'University of North Carolina at Chapel Hill', regex=True)
temp[temp.str.contains('North Carolina')]
# Out:
# 21         North Carolina State University - Raleigh
# 112         University of North Carolina - Asheville
# 131          University of North Carolina - Wilming.
# 154      University of North Carolina at Chapel Hill
# 158         University of North Carolina - Charlotte
# 471    University of North Carolina Sch. of the Arts
# Name: University, dtype: object

# %%
aid.University = aid.University.str.replace('University of North Carolina .+ Hill', 'University of North Carolina at Chapel Hill', regex=True)

# %%
colleges[~colleges.University.isin(aid.University)]
# Out:
#                                     University  Large  Medium Public  \
# 63  University of Illinois at Urbana-Champaign   True   False   True
#
#     Liberal Arts  Small  Rank Private
# 63         False  False  64.0   False

# %%
aid[aid.University.str.contains('Urbana')]
# Out:
#                                  University  Total Cost of Attendance  \
# 156  University of Illinois - Urbana Champ.                   31760.0
#
#      Full-Time Undergrads  Full-Time Nonresident Aliens   \
# 156               31760.0                         4854.0
#
#      Percentage of Nonresident Aliens to All Undergrads  Policy: Need-based  \
# 156                                               15.0                False
#
#      Policy: Merit  Policy: No Aid  \
# 156           True           False
#
#      Percentage of Nonresident Aliens Receiving Aid  Average Aid Award  \
# 156                                             1.0             7163.0
#
#      Average Cost with Aid  Expected Cost
# 156                24597.0        31688.0

# %%
temp=aid.University.str.replace('.*Urbana.*', 'University of Illinois at Urbana-Champaign', regex=True)
temp[temp.str.contains('Urbana')]
# Out:
# 156    University of Illinois at Urbana-Champaign
# Name: University, dtype: object

# %%
aid.University = temp

# %%
aid[aid.University.str.contains('Urbana')]
# Out:
#                                      University  Total Cost of Attendance  \
# 156  University of Illinois at Urbana-Champaign                   31760.0
#
#      Full-Time Undergrads  Full-Time Nonresident Aliens   \
# 156               31760.0                         4854.0
#
#      Percentage of Nonresident Aliens to All Undergrads  Policy: Need-based  \
# 156                                               15.0                False
#
#      Policy: Merit  Policy: No Aid  \
# 156           True           False
#
#      Percentage of Nonresident Aliens Receiving Aid  Average Aid Award  \
# 156                                             1.0             7163.0
#
#      Average Cost with Aid  Expected Cost
# 156                24597.0        31688.0

# %%
colleges[colleges.University.isin(aid.University)]
# Out:
#                                   University  Large  Medium Public  \
# 0      Massachusetts Institute of Technology  False    True  False
# 1                        Stanford University  False    True  False
# 2                            Yale University  False    True  False
# 3                         Harvard University  False    True  False
# 4                       Princeton University  False    True  False
# ..                                       ...    ...     ...    ...
# 74  University of California - Santa Barbara   True   False   True
# 75                   University of Rochester  False    True  False
# 76             Southern Methodist University  False    True  False
# 77                  Brigham Young University   True   False  False
# 78           Case Western Reserve University  False    True  False
#
#     Liberal Arts  Small  Rank Private
# 0          False  False   1.0    True
# 1          False  False   2.0    True
# 2          False  False   3.0    True
# ...

# %% [markdown]
# Preprocessing of names done!

# %%
combined_data = colleges.join(aid.set_index('University'),how='left', on='University')

# %%
combined_data.head(78)
# Out:
#                                   University  Large  Medium Public  \
# 0      Massachusetts Institute of Technology  False    True  False
# 1                        Stanford University  False    True  False
# 2                            Yale University  False    True  False
# 3                         Harvard University  False    True  False
# 4                       Princeton University  False    True  False
# ..                                       ...    ...     ...    ...
# 74  University of California - Santa Barbara   True   False   True
# 75                   University of Rochester  False    True  False
# 76             Southern Methodist University  False    True  False
# 77                  Brigham Young University   True   False  False
# 78           Case Western Reserve University  False    True  False
#
#     Liberal Arts  Small  Rank Private  Total Cost of Attendance  \
# 0          False  False   1.0    True                   73160.0
# ...

# %%
combined_data.to_csv('school_type_rank_aid.csv')
