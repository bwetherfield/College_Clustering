# %%
import pandas as pd

# %%
df = pd.read_csv('Financial+Aid+for+Nonresident+Alien+Undergraduates+(August,+2019) - modified.csv')

# %%
df.head()
# Out:
#                      Institution Total Cost of Attendance  \
# 0  U. of Massachusetts - Amherst                   31,000
# 1                  U. of Alabama                   26,482
# 2              New C. of Florida                   20,650
# 3            U. of Maine - Orono                   25,088
# 4                  U. of Florida                        0
#
#   Full-Time Undergrads Full-Time Nonresident Aliens   \
# 0               21,481                         1,622
# 1               29,822                           589
# 2                  808                             5
# 3                8,126                           170
# 4               30,887                           742
#
#   Percentage of Nonresident Aliens to All Undergrads  \
# 0                                                 8%
# 1                                                 2%
# 2                                                 1%
# 3                                                 2%
# ...

# %%
df.drop(columns={'Go-To School'}, inplace=True)

# %%
test = df.columns[5]

# %%
' '.join(test.split())
# Out:
# 'Policy: Need-based'

# %%
spacer = lambda str: ' '.join(str.split())

# %%
spacer
# Out:
# <function __main__.<lambda>(str)>

# %%
df.columns
# Out:
# Index(['Institution', 'Total Cost of Attendance', 'Full-Time Undergrads',
#        'Full-Time Nonresident Aliens ',
#        'Percentage of Nonresident Aliens to All Undergrads',
#        'Policy:          Need-based', 'Policy:        Merit',
#        'Policy:             No aid',
#        'Percentage of Nonresident Aliens Receiving Aid1', 'Average Aid Award',
#        'Average Cost with Aid', 'Expected Cost', 'Source'],
#       dtype='object')

# %%
spacer('Policy:          Need-based')
# Out:
# 'Policy: Need-based'

# %%
array = df.columns.values

# %%
df.columns.str.replace(r'\s+', ' ', regex=True)
# Out:
# Index(['Institution', 'Total Cost of Attendance', 'Full-Time Undergrads',
#        'Full-Time Nonresident Aliens ',
#        'Percentage of Nonresident Aliens to All Undergrads',
#        'Policy: Need-based', 'Policy: Merit', 'Policy: No aid',
#        'Percentage of Nonresident Aliens Receiving Aid1', 'Average Aid Award',
#        'Average Cost with Aid', 'Expected Cost', 'Source'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(r'\s+', ' ', regex=True)

# %%
df.columns
# Out:
# Index(['Institution', 'Total Cost of Attendance', 'Full-Time Undergrads',
#        'Full-Time Nonresident Aliens ',
#        'Percentage of Nonresident Aliens to All Undergrads',
#        'Policy: Need-based', 'Policy: Merit', 'Policy: No aid',
#        'Percentage of Nonresident Aliens Receiving Aid1', 'Average Aid Award',
#        'Average Cost with Aid', 'Expected Cost', 'Source'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace('Percentage of Nonresident Aliens Receiving Aid1', 'Percentage of Nonresident Aliens Receiving Aid')

# %%
df.columns = df.columns.str.replace('aid', 'Aid')

# %%
df.columns
# Out:
# Index(['Institution', 'Total Cost of Attendance', 'Full-Time Undergrads',
#        'Full-Time Nonresident Aliens ',
#        'Percentage of Nonresident Aliens to All Undergrads',
#        'Policy: Need-based', 'Policy: Merit', 'Policy: No Aid',
#        'Percentage of Nonresident Aliens Receiving Aid', 'Average Aid Award',
#        'Average Cost with Aid', 'Expected Cost', 'Source'],
#       dtype='object')

# %%
df.head()
# Out:
#                      Institution Total Cost of Attendance  \
# 0  U. of Massachusetts - Amherst                   31,000
# 1                  U. of Alabama                   26,482
# 2              New C. of Florida                   20,650
# 3            U. of Maine - Orono                   25,088
# 4                  U. of Florida                        0
#
#   Full-Time Undergrads Full-Time Nonresident Aliens   \
# 0               21,481                         1,622
# 1               29,822                           589
# 2                  808                             5
# 3                8,126                           170
# 4               30,887                           742
#
#   Percentage of Nonresident Aliens to All Undergrads Policy: Need-based  \
# 0                                                 8%                NaN
# 1                                                 2%                NaN
# 2                                                 1%                NaN
# ...

# %%
df.set_index('Institution', inplace=True)

# %%
df.loc[:, 'Policy: Merit'].replace('x', 'True', inplace=True)

# %%
df.loc[:, 'Policy: Need-based'].replace('x', 'True', inplace=True)

# %%
import numpy as np

# %%
df.loc[:, 'Policy: Merit'].replace(np.nan, 'False', inplace=True)

# %%
df.loc[:, df.columns.str.contains('Policy')] = df.loc[:, df.columns.str.contains('Policy')].replace({np.nan: False, 'x': True})

# %%
df.head()
# Out:
#                               Total Cost of Attendance Full-Time Undergrads  \
# Institution
# U. of Massachusetts - Amherst                   31,000               21,481
# U. of Alabama                                   26,482               29,822
# New C. of Florida                               20,650                  808
# U. of Maine - Orono                             25,088                8,126
# U. of Florida                                        0               30,887
#
#                               Full-Time Nonresident Aliens   \
# Institution
# U. of Massachusetts - Amherst                         1,622
# U. of Alabama                                           589
# New C. of Florida                                         5
# U. of Maine - Orono                                     170
# U. of Florida                                           742
#
#                               Percentage of Nonresident Aliens to All Undergrads  \
# Institution
# ...

# %%
df
# Out:
#                               Total Cost of Attendance Full-Time Undergrads  \
# Institution
# U. of Massachusetts - Amherst                   31,000               21,481
# U. of Alabama                                   26,482               29,822
# New C. of Florida                               20,650                  808
# U. of Maine - Orono                             25,088                8,126
# U. of Florida                                        0               30,887
# ...                                                ...                  ...
# Wesleyan U.                                     73,000                2,918
# Western Washington U.                              NaN               13,840
# Willamette U.                                   65,964                1,604
# William Jewell C.                                  NaN                  NaN
# Wofford C.                                         NaN                  NaN
#
# ...

# %%
df.loc[:, df.columns.str.contains('Full-Time')] = df.loc[:, df.columns.str.contains('Full-Time')].replace(r',', '', regex=True)

# %%
df
# Out:
#                               Total Cost of Attendance Full-Time Undergrads  \
# Institution
# U. of Massachusetts - Amherst                   31,000                21481
# U. of Alabama                                   26,482                29822
# New C. of Florida                               20,650                  808
# U. of Maine - Orono                             25,088                 8126
# U. of Florida                                        0                30887
# ...                                                ...                  ...
# Wesleyan U.                                     73,000                 2918
# Western Washington U.                              NaN                13840
# Willamette U.                                   65,964                 1604
# William Jewell C.                                  NaN                  NaN
# Wofford C.                                         NaN                  NaN
#
# ...

# %%
df.columns = df.columns.str.replace(r'Full-TIme', 'Full-Time', regex=True)

# %%
df.iloc[:,0] = df.iloc[:,0].str.replace(',','')

# %%
df.iloc[:,1] = df.iloc[:,0].str.replace(',','').astype('float')

# %%
df.iloc[:,0] = df.iloc[:,0].astype('float')

# %%
df.iloc[:,2] = df.iloc[:,2].str.replace(',','').astype('float')

# %%
df.tail()
# Out:
#                        Total Cost of Attendance  Full-Time Undergrads  \
# Institution
# Wesleyan U.                             73000.0               73000.0
# Western Washington U.                       NaN                   NaN
# Willamette U.                           65964.0               65964.0
# William Jewell C.                           NaN                   NaN
# Wofford C.                                  NaN                   NaN
#
#                        Full-Time Nonresident Aliens   \
# Institution
# Wesleyan U.                                    364.0
# Western Washington U.                          165.0
# Willamette U.                                   13.0
# William Jewell C.                                NaN
# Wofford C.                                       NaN
#
#                       Percentage of Nonresident Aliens to All Undergrads  \
# Institution
# Wesleyan U.                                                          12%
# ...

# %%
df.iloc[:,3] = df.iloc[:,3].str.replace('%','').astype('float')

# %%
df.iloc[:,7] = df.iloc[:,7].str.replace('%','').astype('float')

# %%
df.iloc[:,8] = df.iloc[:,8].str.replace(',','').astype('float')

# %%
df.iloc[:,9] = df.iloc[:,9].str.replace(',','').astype('float')

# %%
df.iloc[:,10] = df.iloc[:,10].str.replace(',','').astype('float')

# %%
df.head()
# Out:
#                                Total Cost of Attendance  Full-Time Undergrads  \
# Institution
# U. of Massachusetts - Amherst                   31000.0               31000.0
# U. of Alabama                                   26482.0               26482.0
# New C. of Florida                               20650.0               20650.0
# U. of Maine - Orono                             25088.0               25088.0
# U. of Florida                                       0.0                   0.0
#
#                                Full-Time Nonresident Aliens   \
# Institution
# U. of Massachusetts - Amherst                         1622.0
# U. of Alabama                                          589.0
# New C. of Florida                                        5.0
# U. of Maine - Orono                                    170.0
# U. of Florida                                          742.0
#
#                                Percentage of Nonresident Aliens to All Undergrads  \
# Institution
# ...

# %%
df.iloc[:,0].astype('float')
# Out:
# Institution
# U. of Massachusetts - Amherst    31000.0
# U. of Alabama                    26482.0
# New C. of Florida                20650.0
# U. of Maine - Orono              25088.0
# U. of Florida                        0.0
#                                   ...
# Wesleyan U.                      73000.0
# Western Washington U.                NaN
# Willamette U.                    65964.0
# William Jewell C.                    NaN
# Wofford C.                           NaN
# Name: Total Cost of Attendance, Length: 496, dtype: float64

# %%
df.tail()
# Out:
#                        Total Cost of Attendance  Full-Time Undergrads  \
# Institution
# Wesleyan U.                             73000.0               73000.0
# Western Washington U.                       NaN                   NaN
# Willamette U.                           65964.0               65964.0
# William Jewell C.                           NaN                   NaN
# Wofford C.                                  NaN                   NaN
#
#                        Full-Time Nonresident Aliens   \
# Institution
# Wesleyan U.                                    364.0
# Western Washington U.                          165.0
# Willamette U.                                   13.0
# William Jewell C.                                NaN
# Wofford C.                                       NaN
#
#                        Percentage of Nonresident Aliens to All Undergrads  \
# Institution
# Wesleyan U.                                                         12.0
# ...

# %%
df.loc['U. of Massachusetts - Amherst', 'Average Cost with Aid'] = 21858

# %%
df.loc['U. of Massachusetts - Amherst', 'Total Cost of Attendance'] = 31000

# %%
df.loc['U. of Massachusetts - Amherst', 'Expected Cost'] = 26175

# %%
df.head()
# Out:
#                                Total Cost of Attendance  Full-Time Undergrads  \
# Institution
# U. of Massachusetts - Amherst                   31000.0               31000.0
# U. of Alabama                                   26482.0               26482.0
# New C. of Florida                               20650.0               20650.0
# U. of Maine - Orono                             25088.0               25088.0
# U. of Florida                                       0.0                   0.0
#
#                                Full-Time Nonresident Aliens   \
# Institution
# U. of Massachusetts - Amherst                         1622.0
# U. of Alabama                                          589.0
# New C. of Florida                                        5.0
# U. of Maine - Orono                                    170.0
# U. of Florida                                          742.0
#
#                                Percentage of Nonresident Aliens to All Undergrads  \
# Institution
# ...

# %%
df.dtypes
# Out:
# Total Cost of Attendance                              float64
# Full-Time Undergrads                                  float64
# Full-Time Nonresident Aliens                          float64
# Percentage of Nonresident Aliens to All Undergrads    float64
# Policy: Need-based                                     object
# Policy: Merit                                          object
# Policy: No Aid                                         object
# Percentage of Nonresident Aliens Receiving Aid        float64
# Average Aid Award                                     float64
# Average Cost with Aid                                 float64
# Expected Cost                                         float64
# Source                                                 object
# dtype: object

# %%
df.dtypes.reset_index()
# Out:
#                                                 index        0
# 0                            Total Cost of Attendance  float64
# 1                                Full-Time Undergrads  float64
# 2                       Full-Time Nonresident Aliens   float64
# 3   Percentage of Nonresident Aliens to All Underg...  float64
# 4                                  Policy: Need-based   object
# 5                                       Policy: Merit   object
# 6                                      Policy: No Aid   object
# 7      Percentage of Nonresident Aliens Receiving Aid  float64
# 8                                   Average Aid Award  float64
# 9                               Average Cost with Aid  float64
# 10                                      Expected Cost  float64
# 11                                             Source   object

# %%
for i in range(4,7):
    df.iloc[:,i] = df.iloc[:,i].astype('bool')

# %%
df.tail()
# Out:
#                        Total Cost of Attendance  Full-Time Undergrads  \
# Institution
# Wesleyan U.                             73000.0               73000.0
# Western Washington U.                       NaN                   NaN
# Willamette U.                           65964.0               65964.0
# William Jewell C.                           NaN                   NaN
# Wofford C.                                  NaN                   NaN
#
#                        Full-Time Nonresident Aliens   \
# Institution
# Wesleyan U.                                    364.0
# Western Washington U.                          165.0
# Willamette U.                                   13.0
# William Jewell C.                                NaN
# Wofford C.                                       NaN
#
#                        Percentage of Nonresident Aliens to All Undergrads  \
# Institution
# Wesleyan U.                                                         12.0
# ...

# %%
df.dtypes
# Out:
# Total Cost of Attendance                              float64
# Full-Time Undergrads                                  float64
# Full-Time Nonresident Aliens                          float64
# Percentage of Nonresident Aliens to All Undergrads    float64
# Policy: Need-based                                       bool
# Policy: Merit                                            bool
# Policy: No Aid                                           bool
# Percentage of Nonresident Aliens Receiving Aid        float64
# Average Aid Award                                     float64
# Average Cost with Aid                                 float64
# Expected Cost                                         float64
# dtype: object

# %%
df.to_csv('university-aid.csv')
